# %%
#Carga de librerias
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

# %%
#Carga de csv
pop = pd.read_csv('World population.csv', na_values = ' ')

# %%
pop.head()
# Out:
#                Country      Continent  Date       GDP      GNI  \
# 0             Algeria          Africa  2010  188681.0   8310.0
# 1        Aland Islands         Europe  2009       NaN   1140.0
# 2  Antigua and Barbuda  North America  2010    1118.0  17900.0
# 3            Argentina  South America  2010  446044.0  17130.0
# 4             Armenia            Asia  2007   10248.0   6100.0
#
#    Live births number  Live births rate  Deaths number  Death rate  \
# 0            887810.0              24.7       157000.0         NaN
# 1               267.0               9.7          247.0         9.0
# 2              1255.0              13.8          491.0         5.4
# 3            756176.0              18.7       318602.0         7.9
# 4             40105.0              12.4        26830.0         8.3
#
#    Rate of increase  Infant deaths number  \
# 0               NaN                   NaN
# 1               0.7                   NaN
# 2               8.4                  11.0
# ...

# %%
pop.tail()
# Out:
#                                                Country      Continent  Date  \
# 100  United Kingdom of Great Britain and Northern I...         Europe  2008
# 101                                      United States  North America  2008
# 102                                            Uruguay  South America  2008
# 103                Venezuela (Bolivarian Republic of)   South America  2007
# 104                                           Viet Nam           Asia  2011
#
#             GDP      GNI  Live births number  Live births rate  Deaths number  \
# 100   2445408.0  36010.0            794383.0              12.9       579697.0
# 101  14991300.0  48820.0           4247694.0              14.0      2471984.0
# 102     46710.0  14640.0             53199.0              16.0        31363.0
# 103    316482.0   4330.0            615371.0              22.4       118594.0
# 104    123600.0  12430.0                 NaN               NaN            NaN
#
# ...

# %%
#Eliminamos filas con valores NaN
pop.dropna()
# Out:
#                                                Country      Continent  Date  \
# 3                                            Argentina  South America  2010
# 4                                             Armenia            Asia  2007
# 5                                           Australia         Oceania  2010
# 6                                             Austria          Europe  2010
# 13                                  Brunei Darussalam            Asia  2008
# 14                                           Bulgaria          Europe  2010
# 15                                              Canada  North America  2008
# 17                               China, Hong Kong SAR            Asia  2009
# 20                                          Costa Rica  North America  2010
# 22                                              Cyprus           Asia  2007
# 23                                     Czech Republic          Europe  2010
# ...

# %%
#Obtenemos el max value de cada uno de los tipos de datos
pop.max()
# Out:
# Country                                      Viet Nam
# Continent                               South America
# Date                                             2011
# GDP                                       1.49913e+07
# GNI                                             86440
# Live births number                        4.24769e+06
# Live births rate                                 32.4
# Deaths number                             2.47198e+06
# Death rate                                         18
# Rate of increase                                 26.7
# Infant deaths number                           288192
# Infant deaths rate (per 1000 births)             75.2
# Life expectancy at birth male                    79.9
# Life expectancy at birth female                  86.4
# Total fertility rate                             5.42
# dtype: object

# %%
#Obtenemos el min value de cada uno de los tipos de datos
pop.min()
# Out:
# Country                                 Aland Islands
# Continent                                      Africa
# Date                                             2007
# GDP                                               484
# GNI                                               870
# Live births number                                 35
# Live births rate                                  7.5
# Deaths number                                      41
# Death rate                                        1.1
# Rate of increase                                 -4.8
# Infant deaths number                                6
# Infant deaths rate (per 1000 births)              1.7
# Life expectancy at birth male                    42.2
# Life expectancy at birth female                  43.1
# Total fertility rate                             1.04
# dtype: object

# %%
#Obtenemos la mediana de los datos (Country y Continent no aplican por ser datos str)
pop.median()
# Out:
# Date                                     2010.00
# GDP                                     95994.00
# GNI                                     16940.00
# Live births number                      80290.00
# Live births rate                           12.40
# Deaths number                           53445.00
# Death rate                                  8.10
# Rate of increase                            4.10
# Infant deaths number                      480.50
# Infant deaths rate (per 1000 births)        5.30
# Life expectancy at birth male              72.50
# Life expectancy at birth female            78.70
# Total fertility rate                        1.81
# dtype: float64

# %%
#Obtenemos el promedio de los datos (Country y Continent no aplican por ser datos str)
pop.mean()
# Out:
# Date                                      2009.257143
# GDP                                     600780.301075
# GNI                                      22902.947368
# Live births number                      402767.927835
# Live births rate                            14.569880
# Deaths number                           207372.884211
# Death rate                                   8.301282
# Rate of increase                             5.620779
# Infant deaths number                      8039.075000
# Infant deaths rate (per 1000 births)         8.424590
# Life expectancy at birth male               71.848571
# Life expectancy at birth female             77.394286
# Total fertility rate                         1.943600
# dtype: float64

# %%
#Obtenemos el standard-deviation de los datos (Country y Continent no aplican por ser datos str)
pop.std()
# Out:
# Date                                    1.168732e+00
# GDP                                     1.751253e+06
# GNI                                     2.063400e+04
# Live births number                      7.804396e+05
# Live births rate                        5.861880e+00
# Deaths number                           3.952717e+05
# Death rate                              3.204035e+00
# Rate of increase                        6.959400e+00
# Infant deaths number                    3.437871e+04
# Infant deaths rate (per 1000 births)    1.003120e+01
# Life expectancy at birth male           7.034012e+00
# Life expectancy at birth female         7.305449e+00
# Total fertility rate                    7.023987e-01
# dtype: float64
