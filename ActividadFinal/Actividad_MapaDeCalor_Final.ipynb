# %%
# Importar las librerías a utilizar
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

import matplotlib.pylab as plt
import numpy as np

# %%
# Leer los datos a analizar
csmk = pd.read_csv("Child Smokers.csv", na_values = ' ')
print('shape: ', csmk.shape)
csmk = csmk.replace('non', 0)
csmk = csmk.replace('smoker', 1)
csmk = csmk.replace('female', 0)
csmk = csmk.replace('male', 1)
csmk
#para vizualizar mejor smoker y sex se cambian a valores numericos, 1 para si fuma 0 para no,
#igual con sex 0 para female y 1 para male
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e862e06f7ae6> in <module>
#       1 # Leer los datos a analizar
# ----> 2 csmk = pd.read_csv("Child Smokers.csv", na_values = ' ')
#       3 print('shape: ', csmk.shape)
#       4 csmk = csmk.replace('non', 0)
#       5 csmk = csmk.replace('smoker', 1)
#
# ...

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(csmk['Smoker'], bins=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6b682a62cb5a> in <module>
#       2 # un análisis preliminar
#       3 sns.set(rc={'figure.figsize':(11.7,8.27)})
# ----> 4 sns.distplot(csmk['Smoker'], bins=2)
#       5 plt.show()
#
# NameError: name 'csmk' is not defined

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(csmk['Sex'], bins=30)
plt.show()
# Out:
# /home/nicko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(csmk['Age (years)'], bins=30)
plt.show()
# Out:
# /home/nicko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(csmk['Height (cm)'], bins=30)
plt.show()
# Out:
# /home/nicko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se utiliza displot de la librería seaborn para
# un análisis preliminar
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(csmk['FEV (litres)'], bins=30)
plt.show()
# Out:
# /home/nicko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Se obtiene una matriz de correlación
correlation_matrix = csmk.corr().round(3)
# Se usa la matriz de correlación para dibujar un mapa de calor
# annot = True para mostrar los valores dentro del cuadro
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(10,7))

plt.boxplot(csmk)
plt.title("Boxplot")
plt.show()

# %%
fig = plt.figure(figsize=(10,7))

plt.boxplot(csmk['Age (years)'])
plt.title("Boxplot de edad")
plt.show()

# %%
fig = plt.figure(figsize=(10,7))

plt.boxplot(csmk['FEV (litres)'])
plt.title("Boxplot de FEV")
plt.show()

# %%
fig = plt.figure(figsize=(10,7))

plt.boxplot(csmk['Sex'])
plt.title("Boxplot de sexo")
plt.show()

# %%
fig = plt.figure(figsize=(10,7))

plt.boxplot(csmk['Smoker'])
plt.title("Boxplot de fumadores")
plt.show()
